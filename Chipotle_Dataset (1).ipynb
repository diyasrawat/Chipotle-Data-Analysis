# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/content/drive/MyDrive/chipotle.tsv', sep ='\t')

# %% [markdown]
# DATA CLEANING AND MANIPULATION

# %%
data.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
data.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
data.tail()
# Out:
#       order_id  quantity           item_name  \
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
data.describe
# Out:
# <bound method NDFrame.describe of       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
data.shape
# Out:
# (4622, 5)

# %%
# Check for missing values in each column (Order ID, Quantity, Item Name, Choice Description, Item Price). How should missing values be handled?

data.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
# Verify the data types of each column. Do they align with their expected types, and should any adjustments be made?

data.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
data['item_price'] = pd.to_numeric(data['item_price'].str.replace('$', ''), errors='coerce')
# Out:
# <ipython-input-13-36bf760c9cf2>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['item_price'] = pd.to_numeric(data['item_price'].str.replace('$', ''), errors='coerce')

# %%
# Question: Identify and handle duplicated entries in the dataset. How might duplicates impact analysis, and what is the appropriate action?

data.duplicated().sum()
# Out:
# 59

# %%
# remove duplicates
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
# Examine the Quantity and Item Price columns. Are there any inconsistencies or anomalies that need correction?

data['quantity'].value_counts()
# Out:
# 1     4296
# 2      224
# 3       28
# 4       10
# 5        1
# 15       1
# 7        1
# 8        1
# 10       1
# Name: quantity, dtype: int64

# %%
data['item_price'].value_counts()
# Out:
# 8.75     730
# 11.25    521
# 9.25     398
# 4.45     349
# 8.49     311
#         ...
# 13.35      1
# 7.50       1
# 4.36       1
# 11.80      1
# 11.49      1
# Name: item_price, Length: 78, dtype: int64

# %%
# Analyze the Choice Description column. How should choices be handled, especially when there are multiple descriptions for a single item?

data['choice_description'].value_counts()
# Out:
# [Diet Coke]                                                                                                                                      133
# [Coke]                                                                                                                                           115
# [Sprite]                                                                                                                                          77
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]                                                                            41
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]                                                                 38
#                                                                                                                                                 ...
# ...

# %%
# Check for special characters in text-based columns (e.g., Item Name, Choice Description). How can these be addressed for consistency?

data['item_name'].str.contains('[^A-Za-z0-9 ]').sum()
# Out:
# 69

# %%
data['choice_description'].str.contains('[^A-Za-z0-9 ]').sum()
# Out:
# 3376

# %%
data['item_name'] = data['item_name'].str.replace('[^A-Za-z0-9 ]', '', regex=True)

# %%
data
# Out:
#       order_id  quantity                             item_name  \
# 0            1         1          Chips and Fresh Tomato Salsa
# 1            1         1                                  Izze
# 2            1         1                      Nantucket Nectar
# 3            1         1  Chips and TomatilloGreen Chili Salsa
# 4            2         2                          Chicken Bowl
# ...        ...       ...                                   ...
# 4617      1833         1                         Steak Burrito
# 4618      1833         1                         Steak Burrito
# 4619      1834         1                    Chicken Salad Bowl
# 4620      1834         1                    Chicken Salad Bowl
# 4621      1834         1                    Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# 1                                          [Clementine]        3.39
# ...

# %%
# Cross-reference the Order ID column for integrity. Are there any irregularities or patterns that need validation?

data.groupby('order_id').size().reset_index(name='count')
# Out:
#       order_id  count
# 0            1      4
# 1            2      1
# 2            3      2
# 3            4      2
# 4            5      2
# ...        ...    ...
# 1829      1830      2
# 1830      1831      3
# 1831      1832      2
# 1832      1833      2
# 1833      1834      3
#
# [1834 rows x 2 columns]

# %%
# Standardize the Item Name column. Are there variations that can be unified for better analysis?

data['item_name'] = data['item_name'].str.replace('[^A-Za-z0-9 ]', '')
data['item_name'] = data['item_name'].str.lower()
data
# Out:
# <ipython-input-23-b811da2d0051>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['item_name'] = data['item_name'].str.replace('[^A-Za-z0-9 ]', '')
#       order_id  quantity                             item_name  \
# 0            1         1          chips and fresh tomato salsa
# 1            1         1                                  izze
# 2            1         1                      nantucket nectar
# 3            1         1  chips and tomatillogreen chili salsa
# 4            2         2                          chicken bowl
# ...        ...       ...                                   ...
# 4617      1833         1                         steak burrito
# 4618      1833         1                         steak burrito
# 4619      1834         1                    chicken salad bowl
# 4620      1834         1                    chicken salad bowl
# 4621      1834         1                    chicken salad bowl
#
# ...

# %%
# Investigate the relationships between Quantity and Item Price. Are there cases where adjustments need to be made for accurate analysis?

data.groupby('item_name')['quantity', 'item_price'].sum().reset_index()
# Out:
# <ipython-input-26-6f6e08f99f73>:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('item_name')['quantity', 'item_price'].sum().reset_index()
# <ipython-input-26-6f6e08f99f73>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('item_name')['quantity', 'item_price'].sum().reset_index()
#                                 item_name  quantity
# 0                       6 pack soft drink        55
# 1                           barbacoa bowl        65
# 2                        barbacoa burrito        90
# 3                   barbacoa crispy tacos        12
# 4                     barbacoa salad bowl         9
# 5                     barbacoa soft tacos        25
# ...

# %%
# Perform a data integrity check by ensuring that quantities and prices align with the corresponding items and descriptions.

data.columns
data.dtypes
data.isnull().sum()
data['quantity'] = data['quantity'].astype('float')
data['item_price'] = data['item_price'].astype('float')
data['item_name'] = data['item_name'].str.replace('[^A-Za-z0-9 ]', '')
data['item_name'] = data['item_name'].str.lower()
data.groupby(['item_name','quantity']).size().reset_index(name='count')
# Out:
# <ipython-input-30-ce20673cd589>:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['item_name'] = data['item_name'].str.replace('[^A-Za-z0-9 ]', '')
#                  item_name  quantity  count
# 0        6 pack soft drink       1.0     53
# 1        6 pack soft drink       2.0      1
# 2            barbacoa bowl       1.0     65
# 3         barbacoa burrito       1.0     90
# 4    barbacoa crispy tacos       1.0     10
# ..                     ...       ...    ...
# 98     veggie crispy tacos       1.0      1
# 99            veggie salad       1.0      6
# 100      veggie salad bowl       1.0     18
# 101      veggie soft tacos       1.0      6
# 102      veggie soft tacos       2.0      1
#
# [103 rows x 3 columns]

# %%
data['average_price_per_unit'] = data['item_price'] / data['quantity']
data
# Out:
#       order_id  quantity                             item_name  \
# 0            1         1          chips and fresh tomato salsa
# 1            1         1                                  izze
# 2            1         1                      nantucket nectar
# 3            1         1  chips and tomatillogreen chili salsa
# 4            2         2                          chicken bowl
# ...        ...       ...                                   ...
# 4617      1833         1                         steak burrito
# 4618      1833         1                         steak burrito
# 4619      1834         1                    chicken salad bowl
# 4620      1834         1                    chicken salad bowl
# 4621      1834         1                    chicken salad bowl
#
#                                      choice_description  item_price  \
# 0                                                   NaN        2.39
# 1                                          [Clementine]        3.39
# ...

# %%
# For categorical columns (e.g., Item Name), consider encoding or transforming them into a format suitable for analysis.
data_encoded = pd.get_dummies(data, columns=['item_name'], prefix='item')

# Display the resulting DataFrame
print(data_encoded.head())
print(data_encoded.tail())
# Out:
#    order_id  quantity                                 choice_description  \
# 0         1       1.0                                                NaN
# 1         1       1.0                                       [Clementine]
# 2         1       1.0                                            [Apple]
# 3         1       1.0                                                NaN
# 4         2       2.0  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
#
#    item_price  item_6 pack soft drink  item_barbacoa bowl  \
# 0        2.39                       0                   0
# 1        3.39                       0                   0
# 2        3.39                       0                   0
# 3        2.39                       0                   0
# 4       16.98                       0                   0
#
#    item_barbacoa burrito  item_barbacoa crispy tacos  \
# 0                      0                           0
# 1                      0                           0
# ...

# %%
# Ensure consistency in units for Quantity and Item Price. Should any conversions or adjustments be made for uniform analysis?
data['quantity'] = data['quantity'].astype(float)
data['item_price'] = data['item_price'].replace('[\$,]', '', regex=True).astype(float)
data
# Out:
#       order_id  quantity                             item_name  \
# 0            1       1.0          chips and fresh tomato salsa
# 1            1       1.0                                  izze
# 2            1       1.0                      nantucket nectar
# 3            1       1.0  chips and tomatillogreen chili salsa
# 4            2       2.0                          chicken bowl
# ...        ...       ...                                   ...
# 4617      1833       1.0                         steak burrito
# 4618      1833       1.0                         steak burrito
# 4619      1834       1.0                    chicken salad bowl
# 4620      1834       1.0                    chicken salad bowl
# 4621      1834       1.0                    chicken salad bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# 1                                          [Clementine]        3.39
# ...

# %%
# Quantity of each item? Top 5 itEmes available in store

data.groupby('item_name')['quantity'].sum().sort_values(ascending=False).head(5)
# Out:
# item_name
# chicken bowl           752.0
# chicken burrito        584.0
# chips and guacamole    501.0
# steak burrito          383.0
# canned soft drink      340.0
# Name: quantity, dtype: float64

# %%
# which is most ordered item in choice_description? use unique names

data.groupby('choice_description')['quantity'].sum().sort_values(ascending=False).head(3)
# Out:
# choice_description
# [Diet Coke]    158.0
# [Coke]         135.0
# [Sprite]        89.0
# Name: quantity, dtype: float64

# %%
# What is total order count?

data['order_id'].value_counts().sum()
# Out:
# 4563

# %%
# What is reveneu?

data['revenue'] = data['item_price'] * data['quantity']
data.head()
# Out:
#    order_id  quantity                             item_name  \
# 0         1         1          chips and fresh tomato salsa
# 1         1         1                                  izze
# 2         1         1                      nantucket nectar
# 3         1         1  chips and tomatillogreen chili salsa
# 4         2         2                          chicken bowl
#
#                                   choice_description  item_price  \
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
#
#    average_price_per_unit  revenue
# 0                    2.39     2.39
# 1                    3.39     3.39
# 2                    3.39     3.39
# 3                    2.39     2.39
# ...

# %%
total_revenue = data['revenue'].sum()
print("Total Revenue:", total_revenue)
# Out:
# Total Revenue: 39237.02

# %%
# What is average revenue amount per order?

data['revenue'].groupby(data['item_name']).mean()
# Out:
# item_name
# 6 pack soft drink                         6.850556
# barbacoa bowl                            10.201692
# barbacoa burrito                          9.838889
# barbacoa crispy tacos                    12.610000
# barbacoa salad bowl                      10.778889
# barbacoa soft tacos                      10.018400
# bottled water                             4.120516
# bowl                                     37.000000
# burrito                                   7.400000
# canned soda                               1.859412
# canned soft drink                         2.034483
# carnitas bowl                            12.216324
# carnitas burrito                         10.446271
# carnitas crispy tacos                    13.705714
# carnitas salad                            8.990000
# carnitas salad bowl                      11.056667
# carnitas soft tacos                       9.398500
# chicken bowl                             11.104114
# ...

# %%
# Top 5 items
top_items_avg = data.groupby('item_name')['revenue'].mean().sort_values(ascending=False).head(5).mean()

# Bottom 5 items
bottom_items_avg = data.groupby('item_name')['revenue'].mean().sort_values().head(5).mean()

print("Average Revenue for Top 5 Items:", top_items_avg)
print("Average Revenue for Bottom 5 Items:", bottom_items_avg)
# Out:
# Average Revenue for Top 5 Items: 18.175651141961488
# Average Revenue for Bottom 5 Items: 2.3686873047098818

# %%
# How many different items are sold? only name them

print(data['item_name'].nunique())

print(data['item_name'].unique())
# Out:
# 50
# ['chips and fresh tomato salsa' 'izze' 'nantucket nectar'
#  'chips and tomatillogreen chili salsa' 'chicken bowl' 'side of chips'
#  'steak burrito' 'steak soft tacos' 'chips and guacamole'
#  'chicken crispy tacos' 'chicken soft tacos' 'chicken burrito'
#  'canned soda' 'barbacoa burrito' 'carnitas burrito' 'carnitas bowl'
#  'bottled water' 'chips and tomatillo green chili salsa' 'barbacoa bowl'
#  'chips' 'chicken salad bowl' 'steak bowl' 'barbacoa soft tacos'
#  'veggie burrito' 'veggie bowl' 'steak crispy tacos'
#  'chips and tomatillo red chili salsa' 'barbacoa crispy tacos'
#  'veggie salad bowl' 'chips and roasted chilicorn salsa'
#  'chips and roasted chili corn salsa' 'carnitas soft tacos'
#  'chicken salad' 'canned soft drink' 'steak salad bowl'
#  '6 pack soft drink' 'chips and tomatillored chili salsa' 'bowl' 'burrito'
#  'crispy tacos' 'carnitas crispy tacos' 'steak salad'
#  'chips and mild fresh tomato salsa' 'veggie soft tacos'
# ...

# %%
# Find total cost and quantity of every unique items

data.groupby('item_name')['quantity', 'item_price'].sum()
# Out:
# <ipython-input-76-bf134c597fab>:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('item_name')['quantity', 'item_price'].sum()
#                                        quantity  item_price
# item_name
# 6 pack soft drink                          55.0      356.95
# barbacoa bowl                              65.0      663.11
# barbacoa burrito                           90.0      885.50
# barbacoa crispy tacos                      12.0      120.21
# barbacoa salad bowl                         9.0       97.01
# barbacoa soft tacos                        25.0      250.46
# bottled water                             204.0      292.06
# bowl                                        4.0       29.60
# burrito                                     6.0       44.40
# canned soda                               124.0      135.16
# canned soft drink                         340.0      425.00
# ...
